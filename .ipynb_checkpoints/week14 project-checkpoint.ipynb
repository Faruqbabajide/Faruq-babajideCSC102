# %%
#project 1
import pandas as pd

# Create empty lists to store the student details
names = []
matric_numbers = []
departments = []
levels = []

# Input the number of students
num_students = int(input("Enter the number of students: "))

# Input the details of each student
for i in range(num_students):
    print(f"\nEnter details for Student {i+1}:")
    name = input("Name: ")
    matric_number = input("Matric Number: ")
    department = input("Department: ")
    level = input("Level: ")

    # Append the details to respective lists
    names.append(name)
    matric_numbers.append(matric_number)
    departments.append(department)
    levels.append(level)

# Create a dictionary to store the student details
data = {
    "Student Name": names,
    "Matric Number": matric_numbers,
    "Department": departments,
    "Level": levels
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the DataFrame
print("\nStudent Details:")
print(df)

# Save the DataFrame to an Excel file
file_name = input("\nEnter the file name to save as (without extension): ")
df.to_excel(f"{file_name}.xlsx", index=False)
print(f"\nData saved to {file_name}.xlsx file successfully.")

# %%
#Project 2
import pandas as pd

# Create empty lists to store the student details
companies = []
shares = []
liabilities = []

# Input the number of students
num_students = int(input("Enter the number of students: "))

# Input the details of each student
for i in range(num_students):
    print(f"\nEnter details for Student {i+1}:")
    company = input("Company: ")
    share = input("Company's Share: ")
    liability = input("Company Liability: ")

    # Append the details to respective lists
    companies.append(company)
    shares.append(share)
    liabilities.append(liability)

# Create a dictionary to store the student details
data = {
    "Company": companies,
    "Company's Share": shares,
    "Company Liability": liabilities
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Display the DataFrame
print("\nStudent Details:")
print(df)

# Save the DataFrame to an Excel file
file_name = input("\nEnter the file name to save as (without extension): ")
df.to_excel(f"{file_name}.xlsx", index=False)
print(f"\nData saved to {file_name}.xlsx file successfully.")
